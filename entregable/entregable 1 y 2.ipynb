# %%
import pandas as pd

# %%
df = pd.read_csv('Tratados_internacionales_de_Colombia_20241206.csv')

# %%
borrar = df.pop('Temas')

# %%
df
# Out:
#                                      Nombre del Tratado Bilateral  \
# 0                 CONVENCION SOBRE NEUTRALIDAD MARITIMA        NO
# 1     CANJE DE NOTAS QUE CONSTITUYEN UN ACUERDO MUTU...        SI
# 2     ACUERDO DE COOPERACION ENTRE EL GOBIERNO DE LA...        SI
# 3     ACUERDO REGIONAL SOBRE EL ACCESO A LA INFORMAC...        NO
# 4     CONVENCION MULTILATERAL PARA APLICAR LAS MEDID...        NO
# ...                                                 ...       ...
# 2797  CANJE DE NOTAS QUE CONSTITUYE UN ACUERDO SOBRE...        SI
# 2798  CONVENIO CULTURAL ENTRE EL GOBIERNO DE LA REPU...        SI
# 2799  CANJE DE NOTAS QUE CONSTITUYE UN ACUERDO ENTRE...        SI
# 2800  MEMORANDO DE ENTENDIMIENTO ENTRE LOS GOBIERNOS...        SI
# 2801  ACUERDO ENTRE EL GOBIERNO DE LA REPUBLICA DE C...        SI
#
#      Lugar de Adopcion Fecha de Adopcion  \
# 0            LA HABANA        20/02/1928
# 1               BOGOTA        06/09/2022
# 2               BOGOTA        07/06/1988
# 3               ESCAZU        04/03/2018
# 4                PARIS        07/06/2017
# ...                ...               ...
# 2797            BOGOTA        31/08/1998
# 2798            BEIJIN        01/10/1981
# 2799            SKOPJE        22/06/2000
# 2800            BOGOTA        09/09/2004
# 2801          NUSA DUA        10/06/2013
#
#                                      Estados-Organismos          Temas  \
# 0                ORGANIZACIÓN DE ESTADOS AMERICANOS-OEA  (NO REGISTRA)
# 1                                             DINAMARCA  (NO REGISTRA)
# 2     INSTITUTO LATINOAMERICANO DE LAS NACIONES UNID...  (NO REGISTRA)
# 3               ORGANIZACIÓN DE LAS NACIONES UNIDAS-ONU  (NO REGISTRA)
# 4     ORGANIZACIÓN PARA LA COOEPRACION Y EL DESARROL...  (NO REGISTRA)
# ...                                                 ...            ...
# 2797                            CHINA REPUBLICA POPULAR  (NO REGISTRA)
# 2798                            CHINA REPUBLICA POPULAR  (NO REGISTRA)
# 2799                                          MACEDONIA  (NO REGISTRA)
# 2800                                       PAISES BAJOS  (NO REGISTRA)
# 2801                                          INDONESIA  (NO REGISTRA)
#
#                   Naturaleza del Tratado  \
# 0                                TRATADO
# 1     ACUERDO PROCEDIMIENTO SIMPLIFICADO
# 2                                TRATADO
# 3                                TRATADO
# 4                                TRATADO
# ...                                  ...
# 2797  ACUERDO PROCEDIMIENTO SIMPLIFICADO
# 2798                             TRATADO
# 2799  ACUERDO PROCEDIMIENTO SIMPLIFICADO
# 2800  ACUERDO PROCEDIMIENTO SIMPLIFICADO
# 2801                             TRATADO
#
#                                   Depositario  \
# 0      ORGANIZACIÓN DE ESTADOS AMERICANOS-OEA
# 1                               (NO REGISTRA)
# 2                               (NO REGISTRA)
# 3     ORGANIZACIÓN DE LAS NACIONES UNIDAS-ONU
# 4                               (NO REGISTRA)
# ...                                       ...
# 2797                            (NO REGISTRA)
# 2798                            (NO REGISTRA)
# 2799                            (NO REGISTRA)
# 2800                            (NO REGISTRA)
# 2801                            (NO REGISTRA)
#
#                                  Suscribio Por Colombia Vigente  \
# 0                                 ENRIQUE OLAYA HERRERA      SI
# 1                                         (NO REGISTRA)      SI
# 2     ENRIQUE LOW MURTRA - MINISTRO DE JUSTICIA, ENC...      SI
# 3     GUILLERMO ROQUE FERNANDEZ DE SOTO VALDERRAMA -...      NO
# 4                                         (NO REGISTRA)      NO
# ...                                                 ...     ...
# 2797  MARIA FERNANDA CAMPO SAAVEDRA - VICEMINISTRA D...      SI
# 2798                                           ILEGIBLE      SI
# 2799  GUILLERMO FERNANDEZ DE SOTO MINISTRO DE RELACI...      SI
# 2800   CAROLINA BARCO MINISTRA DE RELACIONES EXTERIORES      SI
# 2801  ALFONSO GARZON MENDEZ - EMBAJADOR DE COLOMBIA ...      SI
#
#      Fecha Ley Aprobatoria Numero Ley Aprobatoria Sentencia Fecha Ley  \
# 0               27/05/1931             69 DE 1931          17/01/1941
# 1            (NO REGISTRA)          (NO REGISTRA)          13/09/2022
# 2               04/10/1989             43 DE 1989          20/10/2006
# 3               05/11/2022        LEY 2273 DE2022       (NO REGISTRA)
# 4            (NO REGISTRA)          (NO REGISTRA)       (NO REGISTRA)
# ...                    ...                    ...                 ...
# 2797         (NO REGISTRA)          (NO REGISTRA)          31/08/1998
# 2798            07/02/1984              6 DE 1984          07/03/1984
# 2799         (NO REGISTRA)          (NO REGISTRA)          22/06/2000
# 2800         (NO REGISTRA)          (NO REGISTRA)          09/09/2010
# 2801         (NO REGISTRA)          (NO REGISTRA)          26/03/2014
#
#      Sentencia Numero Decreto Fecha Diario Oficial  \
# 0       (NO REGISTRA)                (NO REGISTRA)
# 1       (NO REGISTRA)                (NO REGISTRA)
# 2       (NO REGISTRA)                (NO REGISTRA)
# 3       (NO REGISTRA)                (NO REGISTRA)
# 4       (NO REGISTRA)                (NO REGISTRA)
# ...               ...                          ...
# 2797    (NO REGISTRA)                (NO REGISTRA)
# 2798    (NO REGISTRA)                   22/03/1985
# 2799    (NO REGISTRA)                (NO REGISTRA)
# 2800    (NO REGISTRA)                (NO REGISTRA)
# 2801    (NO REGISTRA)                (NO REGISTRA)
#
#      Decreto Numero Diario Oficial
# 0                    (NO REGISTRA)
# 1                    (NO REGISTRA)
# 2                    (NO REGISTRA)
# 3                    (NO REGISTRA)
# 4                    (NO REGISTRA)
# ...                            ...
# 2797                 (NO REGISTRA)
# 2798                   845 DE 1985
# 2799                 (NO REGISTRA)
# 2800                 (NO REGISTRA)
# 2801                 (NO REGISTRA)
#
# [2802 rows x 16 columns]

# %%
#COLUMNAS DE INTERES

#TRATADOS INTERNACIONALES DE COLOMBIA CON ALREDEDOR DEL MUNDO

#-NOMBRE DEL TRATADO= es importante tener en cuent ael tratado que se hzio y su razon
#-bilateral= en necesario saber si entre las dos naciones que hcieron el tratado hubieron beneficios 
#lugar de adopcion= es necesario saber el origen del lugar donde se hizo el tratado
#fecha de adopcion= la fecha del dia del tratado es de suma importancia tenerla  
# estados-organismos = es importante resaltar el estado y organismos parar tenrer mas especificacion de donde se hizo el tratado
# naturaleza del tratado= saber el proceso del tratado (tratado,desacuerdo o en proceso)
#  depositario= organizacion que esta al tanto de los tratados de los paises
#suscribio por colombia= importante tener en cuenta el encargado del tratado de colombia
# vigente= es important saber si esta en activo o desactivo el tratado 
# fecha ley aprobatoria= fecha de dia en el que se aprobo la ley del tratado
# numero ley aprobatoria= es importante tener el numero de ley establecido 
# sentecia fecha ley= es iportante saber el dia de que se puso la sentencia de ley

# %%
    #ACTIVIDAD 2
# 1-
#en que lugares fueron adoptados la mayoria de tratados internacionales?

# %%
import matplotlib.pyplot as plt
import seaborn as sns
import pandas as pd
import numpy as np

# %%
df.columns
# Out:
# Index(['Nombre del Tratado', 'Bilateral', 'Lugar de Adopcion',
#        'Fecha de Adopcion', 'Estados-Organismos', 'Naturaleza del Tratado',
#        'Depositario', 'Suscribio Por Colombia', 'Vigente',
#        'Fecha Ley Aprobatoria', 'Numero Ley Aprobatoria',
#        'Sentencia Fecha Ley', 'Sentencia Numero',
#        'Decreto Fecha Diario Oficial', 'Decreto Numero Diario Oficial'],
#       dtype='object')

# %%
lugares_adopcion= df['Lugar de Adopcion']

# %%
frecuencia_lugares= lugares_adopcion.value_counts().nlargest(10)

# %%
plt.figure(figsize=(9, 9))
plt.pie(frecuencia_lugares.values, labels=frecuencia_lugares.index, autopct='%1.1f%%')
plt.title('Lugares de adopción de tratados internacionales')
plt.axis('equal')  


plt.show()

# %%
#de esta forma de grafica de pastel, podemos saber cuales fueron la mayoria de los mas nombrados etre los primeros
#10 mas nombrados de la tabla.

#(usando matiplotlib)

# %%
#SEGUNDO PUNTO

#2-¿ cual es la distribucion de tratados internacionales por tipo de naturaleza ?

# %%
import seaborn as sns
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
df.columns
# Out:
# Index(['Nombre del Tratado', 'Bilateral', 'Lugar de Adopcion',
#        'Fecha de Adopcion', 'Estados-Organismos', 'Temas',
#        'Naturaleza del Tratado', 'Depositario', 'Suscribio Por Colombia',
#        'Vigente', 'Fecha Ley Aprobatoria', 'Numero Ley Aprobatoria',
#        'Sentencia Fecha Ley', 'Sentencia Numero',
#        'Decreto Fecha Diario Oficial', 'Decreto Numero Diario Oficial'],
#       dtype='object')

# %%
naturaleza = df['Naturaleza del Tratado']

# %%
plt.figure(figsize=(11, 8))
naturaleza.value_counts().plot(kind='bar', color ='green')
plt.title('Distribución de tratados internacionales por naturaleza')
plt.xlabel('Naturaleza')
plt.ylabel('Cantidad de tratados')
plt.xticks(rotation=90)

plt.show()

# %%
#de esta forma podemos ver la diferencia en donde se hizo el tratado y
# donde hubo un acuerdo en los tratados internacionales


# (usando seaborn)

# %%
#   PREGUNTA 3

""""
se necesita las ultimas 10 ciudades mas nombradas y cuantas veces se hizo un tratado de adopcio con su debido año, para poder verificar cual
es la ciudad con mas tratados de adopcion(en la seccion llamda = grafica_plotly.py en la carpeta de entregable )
"""
# Out:
# '"\nse necesita las ultimas 10 ciudades mas nombradas y cuantas veces se hizo un tratado de adopcio con su debido año, para poder verificar cual\nes la ciudad con mas tratados de adopcion(en la seccion llamda = grafica_plotly.py en la carpeta de entregable )\n'
